# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import json
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file = open("/content/drive/My Drive/coll bb_SortByConf.json")
data = json.load(file)
df = pd.DataFrame(data["teams"])

vaTeams = df.loc[df["state"] == "VA"]
mascotGrouped = df.groupby("name").count()
mascotGrouped = mascotGrouped.loc[mascotGrouped["tid"] > 1]

pd.set_option("display.max_rows", 100)
df.head(100)
# Out:
#     tid  cid  did                region              name  abbrev  pop  \
# 0   159    0    0        Boston College            Eagles      BC  161
# 1   105    0    0               Clemson            Tigers    CLEM  215
# 2   109    0    0         Florida State         Seminoles     FSU  211
# 3    18    0    0            Louisville         Cardinals      UL  302
# 4    31    0    0  North Carolina State          Wolfpack    NCST  289
# 5     9    0    0            Notre Dame    Fighting Irish      ND  311
# 6    66    0    0              Syracuse            Orange    CUSE  254
# 7   141    0    0           Wake Forest     Demon Deacons    WAKE  179
# 8     0    0    1                  Duke       Blue Devils    DUKE  320
# 9   145    0    1          Georgia Tech    Yellow Jackets      GT  175
# 10   47    0    1                 Miami       Hurricanes    CANES  273
# 11    8    0    1        North Carolina         Tar Heels     UNC  312
# ...

# %%
print(f"\nNumber of teams: {len(df.index)}")
print(f"Number of teams in Virginia: {len(vaTeams.index)}")
print(f"Teams grouped by duplicated mascot: \n\n {mascotGrouped['tid'].to_string()}")
# Out:
# Number of teams: 320
# Number of teams in Virginia: 13
# Teams grouped by duplicated mascot:
#
#  name
# 49ers             2
# Aggies            4
# Bears             4
# Bison             2
# Bisons            2
# Bobcats           3
# Broncos           3
# Bruins            2
# Buccaneers        2
# Bulldogs         13
# Bulls             2
# Cardinals         4
# Catamounts        2
# Colonials         2
# Cougars           4
# Cowboys           3
# Crusaders         2
# Dukes             2
# Eagles           10
# Falcons           2
# Gaels             2
# Gamecocks         2
# Golden Eagles     4
# Hawks             4
# Highlanders       2
# Hornets           3
# Huskies           5
# Jaguars           3
# Knights           2
# Lions             2
# Lumberjacks       2
# Mavericks         2
# Mountaineers      3
# Mustangs          2
# Owls              4
# Panthers          8
# Phoenix           2
# Pioneers          2
# Pirates           3
# Raiders           2
# ...
